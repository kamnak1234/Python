# %%
import seaborn as sns

# %% [raw]
# To view inbuilt dataset

# %%
print(sns.get_dataset_names())
# Out:
# ['anagrams', 'anscombe', 'attention', 'brain_networks', 'car_crashes', 'diamonds', 'dots', 'exercise', 'flights', 'fmri', 'geyser', 'iris', 'mpg', 'penguins', 'planets', 'taxis', 'tips', 'titanic']

# %%
a = sns.load_dataset('titanic')

# %%
a
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
a.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %% [markdown]
# # A. Statitiscal Relationship (sns.relplot())

# %% [raw]
# 1. Scatter Plot(default)

# %%
sns.relplot(data=a, x='age', y='fare')

# %% [raw]
# 2. line plot

# %%
sns.relplot(data=a, x='age', y='fare', kind='line')

# %% [raw]
# Differentiate with one paarameter

# %%
# column
sns.relplot(data=a, x='age', y='fare',col='sex')

# %%
# row
sns.relplot(data=a, x='age', y='fare',row='sex')

# %% [raw]
# Differentiate with two paarameter

# %%
sns.relplot(data=a, x='age', y='fare',col='sex',row='alone', hue='alive', size = 'pclass')
sns.despine(trim = True, offset= 10)

# %% [markdown]
# # B. Categorical Relationship (sns.catplot())

# %%
a
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %% [raw]
# 1.Scatter Plot (strip(), sworm()) # default

# %%
#strip()

# %%
sns.catplot(data=a, x='embark_town', y='fare',kind='strip')

# %%
sns.catplot(data=a, x='embark_town', y='fare',kind='strip', jitter=False)

# %%
sns.catplot(data=a, x='sex', y='fare',kind='strip', jitter=False)

# %%
#sworm()

# %%
sns.catplot(data=a, x='embark_town', y='fare',kind='swarm',col='sex',hue='alive')
# Out:
# C:\Python\Python38\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 70.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Python\Python38\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 21.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Python\Python38\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 29.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Python\Python38\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 46.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# ...

# %% [raw]
# 2. Distribution (boxplot(), violinplot(), boxenplot())

# %%
a=sns.load_dataset('taxis')

# %%
a
# Out:
#                    pickup              dropoff  passengers  distance  fare  \
# 0     2019-03-23 20:21:09  2019-03-23 20:27:24           1      1.60   7.0
# 1     2019-03-04 16:11:55  2019-03-04 16:19:00           1      0.79   5.0
# 2     2019-03-27 17:53:01  2019-03-27 18:00:25           1      1.37   7.5
# 3     2019-03-10 01:23:59  2019-03-10 01:49:51           1      7.70  27.0
# 4     2019-03-30 13:27:42  2019-03-30 13:37:14           3      2.16   9.0
# ...                   ...                  ...         ...       ...   ...
# 6428  2019-03-31 09:51:53  2019-03-31 09:55:27           1      0.75   4.5
# 6429  2019-03-31 17:38:00  2019-03-31 18:34:23           1     18.74  58.0
# 6430  2019-03-23 22:55:18  2019-03-23 23:14:25           1      4.14  16.0
# 6431  2019-03-04 10:09:25  2019-03-04 10:14:29           1      1.12   6.0
# 6432  2019-03-13 19:31:22  2019-03-13 19:48:02           1      3.85  15.0
#
# ...

# %%
#boxplot()

# %%
sns.catplot(data = a, x='pickup_borough', y='fare',kind='box')

# %%
sns.catplot(data = a, x='pickup_borough', y='fare',kind='box',hue='color',linewidth=2.5,dodge=False)

# %%
#boxen()

# %%
sns.catplot(data = a, x='pickup_borough', y='fare',kind='boxen',hue='color')

# %%
#mix plot for same value
g = sns.catplot( x='pickup_borough', y='fare',data = a,inner=None, kind='boxen')
sns.catplot(data = a, x='pickup_borough', y='fare',kind='strip',color='red',ax=g.ax)
#sns.swarmplot(x="day", y="total_bill", ", size=3, data=tips, ax=g.ax)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_11916/1847658911.py in <module>
#       1 #mix plot for same value
# ----> 2 g = sns.catplot( x='pickup_borough', y='fare',data = a,inner=None, kind='boxen')
#       3 sns.catplot(data = a, x='pickup_borough', y='fare',kind='strip',color='red',ax=g.ax)
#       4 #sns.swarmplot(x="day", y="total_bill", ", size=3, data=tips, ax=g.ax)
#
# C:\Python\Python38\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ...

# %%
#violin()

# %%
a=sns.load_dataset('titanic')

# %%
sns.catplot(data =a, x = 'class', y = 'age', kind ='violin')

# %%
sns.catplot(data =a, x = 'class', y = 'age', kind ='violin',hue='alive')

# %%
sns.catplot(data = a, x = 'class', y = 'age', kind ='violin', hue='alive', split=True)

# %%
#changing the axes
sns.catplot(data = a, x = 'age', y = 'class', kind ='violin', hue='alive', split=True)

# %%
sns.catplot(data = a, x = 'class', y = 'age', kind ='violin', hue='alive',inner="stick",palette="deep", split=True)

# %% [raw]
# 3. Estimate (barplot())

# %%
 a
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
sns.catplot(data=a,x='class',y='fare',kind='bar')

# %%
sns.catplot(data=a,x='class',y='fare',kind='bar',hue='sex')

# %%
sns.catplot(data=a,x='class',y='fare',kind='bar',hue='sex',palette='colorblind')

# %%
# point plot 
sns.catplot(x="sex", y="survived", hue="class", kind="point", data=a)

# %% [markdown]
# # C.Distribution of data (sns.displot.sns.jointplot,sns.pairplot)

# %% [raw]
# 1. distribution univariant(displot)

# %%
sns.displot(a['age'])

# %%
#increases band width
sns.displot(a['age'],binwidth=10)

# %%
#increases the bins
sns.displot(a['age'],bins=20)

# %%
#curve
sns.displot(a['age'],kind='kde')

# %%
#curve and bar both
sns.displot(a['age'], kde = True, rug=True)

# %%
rug and bins 
sns.displot(a['age'], kde = True, rug=True,bins=90)

# %%
#discrete avoid the gaps 
sns.displot(a, x="age", discrete=True)

# %%
#shrink to add thye gap as per passing value 
sns.displot(a, x="age",shrink=.8)

# %%
#hue will show the overlap bar 
sns.displot(a, x="age",shrink=.8,hue='sex')

# %%
# element to avoid the overlap
sns.displot(a, x="age",shrink=.8,hue='sex',element='step')

# %%
#to overlapp the multiple data 
sns.displot(a, x="age",shrink=.8,hue='sex',multiple="stack")

# %%
#multiple data one after another 
sns.displot(a, x="age",shrink=.8,hue='sex',multiple="dodge")

# %%
sns.displot(a, x="age", hue="sex", kind="kde", multiple="stack")

# %% [raw]
# 2. distribution bivariant(joinplot)

# %%
a
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
sns.jointplot(data = a, x = 'pclass', y = 'age')

# %%
#sns.jointplot(data = a, x = 'pclass', y = 'age')

# %%
#hue
sns.jointplot(data = a, x = 'pclass', y = 'age',hue='sex')

# %%
#kind = kde 
sns.jointplot(data = a, x = 'pclass', y = 'age',hue='sex',kind='kde')

# %%
#kind=hex
sns.jointplot(data = a, x = 'pclass', y = 'age',kind='hex')

# %%
sns.jointplot(data = a, x = 'pclass', y = 'age',kind='hex',color='red')

# %% [raw]
# 3.Pairplot

# %%
iris = sns.load_dataset('iris')

# %%
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
sns.pairplot(iris)
